# %%
# Install dependencies in your env if needed:
# pip install -r ../requirements.txt
from agent_tools import EmbeddingStore
import json, os
store = EmbeddingStore(path="demo_store.db")
# ingest sample docs folder
docs_dir = os.path.join('..', 'docs')
if os.path.exists(docs_dir):
    store.ingest_dir(docs_dir)
# ingest small data file of recipes as an example
data_path = os.path.join('..', 'data', 'recipes.json')
if os.path.exists(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        recipes = json.load(f)
    # add each recipe as a small doc
    for i, r in enumerate(recipes):
        txt = f
